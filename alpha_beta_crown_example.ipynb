# %%
from verifier import ABCrown
import torch

# %%
net = torch.nn.Linear(28, 3).to('mps')
verifier = ABCrown(device='cpu')
image = torch.rand(28)

# %%
a = verifier.verify(net, image, 3, 2, 0.00000000001)
